# %%
x = int(input("How many Fibonnaci numberts to print"))

a = 0
b = 1
c = 0

for i in range(x):
    """ a=b
    b = c+a
    c= a """

    #Or this concise code

    a, b=b, a+b
    print(a , end = " ")
# Out:
# 1 1 2 3 5 8 13
